# %%
from ingest import load_faq_data, build_index
from rag_helper import RAGBase
import os
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("OPENROUTER_API_KEY"),
)

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
assistant = RAGBase(index, client)

# %%
assistant.rag("When this course start?")
# Out:
# "The course can be started at any time since the videos and GitHub materials are available. You don't have to wait for a specific start date."

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

assistant = RAGBase(
    index=index,
    llm_client=client,
    instructions=custom_instructions,
)

# %%
assistant.rag("Can I still join the course after it started?")
# Out:
# 'Yes, you can still join the course after it has started. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted.'

# %%
assistant.rag("How do I get a certificate?")
# Out:
# 'To get a certificate, you need to finish the course with a "live" cohort. Certificates are not awarded for the self-paced mode, as you must complete peer-reviews for three capstone projects during the course. Additionally, you need to pass the Capstone project to qualify for the certificate, although completing homework is recommended but not mandatory. If you want your official name to appear on the certificate, you should ensure that the second field in your profile is updated with your name as it appears on your identification documents.'
