# %%
from ingest import load_faq_data

documents = load_faq_data()
print(f"Loaded {len(documents)} documents.")
# Out:
# Loaded 1350 documents.

# %%
doc_llm = [doc for doc in documents if doc["course"] == "llm-zoomcamp"]

print(len(doc_llm))
# Out:
# 85

# %%
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
import time

for doc in doc_llm:
    index.add(doc)
    print(f"Added document with question: {doc['question'][:60]}...")  # Print the first 60 characters of the question
    time.sleep(0.1)  # Sleep for 100 milliseconds to avoid overwhelming the database
# Out:
# Added document with question: I just discovered the course. Can I still join?...
# Added document with question: Course: I have registered for the LLM Zoomcamp. When can I e...
# Added document with question: What is the video/zoom link to the stream for the “Office Ho...
# Added document with question: How should I start the course and follow the weekly workflow...
# Added document with question: Leaderboard: I am not on the leaderboard / how do I know whi...
# Added document with question: Certificate: Can I follow the course in a self-paced mode an...
# Added document with question: I missed the first homework - can I still get a certificate?...
# Added document with question: Homework: Why does the content keep changing?...
# Added document with question: When will the course be offered next?...
# Added document with question: Are there any lectures/videos? Where are they?...
# Added document with question: Where can I track the LLM Zoomcamp syllabus, deadlines, home...
# ...

# %%
index.close()
